# %% [markdown]
# ### Feature Engineering
#
# This notebook will cover various ways to create features from the fakes news data set. This will include text analytics, sentiment, readability scores.

# %%
import pandas as pd
import numpy as np
import re
import math
import pickle
import string
import textstat
import time
import random

from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import concurrent.futures

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
sia = SIA()


# this allows jupyter to output more than one line in the notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# C:\Users\Alton\Miniconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
# data = pd.read_csv('data/combinedData.csv') 
data = pd.read_csv('data_wang.csv')

# %%
data.head()
data.columns
# Out:
#     dataset                                              title  \
# 0  Buzzfeed              The Impact of Debates? It's Debatable
# 1  Buzzfeed  Details Emerge About NYC Bomb Suspect Ahmad Kh...
# 2  Buzzfeed  Donald Trump Repeats Calls for Police Profilin...
# 3  Buzzfeed  NY, NJ Bombings Suspect Charged With Attempted...
# 4  Buzzfeed  Trump Surrogates Push Narrative That Clinton S...
#
#                                               author  \
# 0                                        GARY LANGER
# 1  Brian Ross Rhonda Schwartz Mike Levine Stephan...
# 2                                     ALANA ABRAMSON
# 3  EMILY SHAPIRO Aaron Katersky Josh Margolin Mik...
# 4                                      Candace Smith
#
#                                                 text  \
# 0  With the Hillary Clinton-Donald Trump debates ...
# 1  As police today captured the man wanted for qu...
# 2  One day after explosive devices were discovere...
# 3  Ahmad Khan Rahami, earlier named a person of i...
# 4  Donald Trump's surrogates and leading supporte...
#
#                                                  url label
# 0  http://abcnews.go.com/Politics/impact-debates-...  real
# 1  http://abcnews.go.com/US/source-suspect-wanted...  real
# 2  http://abcnews.go.com/Politics/donald-trump-re...  real
# 3  http://abcnews.go.com/US/bombing-incidences-ny...  real
# 4  http://abcnews.go.com/Politics/trump-surrogate...  real
# Index(['dataset', 'title', 'author', 'text', 'url', 'label'], dtype='object')

# %% [markdown]
# ##### Are there any NA's in the data?
#
# Text features don't work very well with NA's. We'll replace NA's with an empty string "" for now.

# %%
data.isnull().any()
# Out:
# dataset    False
# title       True
# author      True
# text        True
# url         True
# label      False
# dtype: bool

# %%
data = data.fillna("")

# %% [markdown]
# ##### Creating the readability ease, grade, and sentiment.
# These computations are expensive, so we use parallel processing to improve the speed

# %%
# %%time

# produces a generator operator
# running for the title of the data
# change max_workers depending on the number of cores in your CPU
with concurrent.futures.ProcessPoolExecutor(max_workers=4) as executor:
    values = data['title']
    reading_ease = executor.map(textstat.flesch_reading_ease, values, chunksize=100)
    reading_grade = executor.map(textstat.flesch_kincaid_grade, values, chunksize=100)
    sentiment = executor.map(sia.polarity_scores, values, chunksize=100)
# Out:
# Wall time: 5.71 s

# %%
# %%time

# produces a generator operator
with concurrent.futures.ProcessPoolExecutor(max_workers=4) as executor:
    values = data['text']
    reading_ease_body = executor.map(textstat.flesch_reading_ease, values, chunksize=100)
    reading_grade_body = executor.map(textstat.flesch_kincaid_grade, values, chunksize=100)
    sentiment_body = executor.map(sia.polarity_scores, values, chunksize=100)
# Out:
# Wall time: 1min 15s

# %%
# %%time

reading_ease = pd.DataFrame({'readability':list(reading_ease)})
reading_grade = pd.DataFrame({'read_grade':list(reading_grade)})
sentiment = pd.DataFrame(list(sentiment))

reading_ease_body = pd.DataFrame({'readability_text':list(reading_ease_body)})
reading_grade_body = pd.DataFrame({'read_grade_text':list(reading_grade_body)})
sentiment_body = pd.DataFrame(list(sentiment_body))
# Out:
# Wall time: 42.9 ms

# %%
sentiment_body.columns = ['compound_text', 'neg_text', 'neu_text', 'pos_text']

# %%
df = pd.concat([data, reading_ease, reading_grade, sentiment, reading_ease_body, reading_grade_body, sentiment_body], axis=1)

# %%
df.head()
# Out:
#     dataset                                              title  \
# 0  Buzzfeed              The Impact of Debates? It's Debatable
# 1  Buzzfeed  Details Emerge About NYC Bomb Suspect Ahmad Kh...
# 2  Buzzfeed  Donald Trump Repeats Calls for Police Profilin...
# 3  Buzzfeed  NY, NJ Bombings Suspect Charged With Attempted...
# 4  Buzzfeed  Trump Surrogates Push Narrative That Clinton S...
#
#                                               author  \
# 0                                        GARY LANGER
# 1  Brian Ross Rhonda Schwartz Mike Levine Stephan...
# 2                                     ALANA ABRAMSON
# 3  EMILY SHAPIRO Aaron Katersky Josh Margolin Mik...
# 4                                      Candace Smith
#
#                                                 text  \
# 0  With the Hillary Clinton-Donald Trump debates ...
# 1  As police today captured the man wanted for qu...
# 2  One day after explosive devices were discovere...
# 3  Ahmad Khan Rahami, earlier named a person of i...
# 4  Donald Trump's surrogates and leading supporte...
#
#                                                  url label  readability  \
# 0  http://abcnews.go.com/Politics/impact-debates-...  real        56.93
# 1  http://abcnews.go.com/US/source-suspect-wanted...  real        62.34
# 2  http://abcnews.go.com/Politics/donald-trump-re...  real        51.85
# 3  http://abcnews.go.com/US/bombing-incidences-ny...  real        69.79
# 4  http://abcnews.go.com/Politics/trump-surrogate...  real        46.44
#
#    read_grade  compound    neg    neu  pos  readability_text  read_grade_text  \
# 0         6.8    0.0000  0.000  1.000  0.0             67.18              9.1
# 1         6.8   -0.6597  0.435  0.565  0.0             46.00             13.1
# 2         8.8    0.0000  0.000  1.000  0.0             68.70              8.5
# 3         6.0   -0.8271  0.554  0.446  0.0             55.07             11.7
# 4         8.8    0.0000  0.000  1.000  0.0             52.12             12.8
#
#    compound_text  neg_text  neu_text  pos_text
# 0         0.9682     0.061     0.851     0.089
# 1        -0.9882     0.095     0.860     0.045
# 2        -0.7769     0.086     0.887     0.028
# 3        -0.9912     0.087     0.864     0.049
# 4        -0.7303     0.074     0.859     0.067

# %% [markdown]
# ##### Implementing Basic Text Feature

# %%
# %%time

df['punctuation_title'] = df['title'].apply(lambda x: len("".join(_ for _ in x if _ in string.punctuation)))
df['punctuation_text'] = df['text'].apply(lambda x: len("".join(_ for _ in x if _ in string.punctuation)))
df['count_text'] = df['text'].apply(lambda x: len(str(x).split(" ")))
df['count_title'] = df['title'].apply(lambda x: len(str(x).split(" ")))
df['punctuation_ratio_text'] = df['punctuation_text']/df['count_text']
df['punctuation_ratio_title'] = df['punctuation_title']/df['count_title']
# Out:
# Wall time: 7.3 s

# %%
df.head()
df.columns
# Out:
#     dataset                                              title  \
# 0  Buzzfeed              The Impact of Debates? It's Debatable
# 1  Buzzfeed  Details Emerge About NYC Bomb Suspect Ahmad Kh...
# 2  Buzzfeed  Donald Trump Repeats Calls for Police Profilin...
# 3  Buzzfeed  NY, NJ Bombings Suspect Charged With Attempted...
# 4  Buzzfeed  Trump Surrogates Push Narrative That Clinton S...
#
#                                               author  \
# 0                                        GARY LANGER
# 1  Brian Ross Rhonda Schwartz Mike Levine Stephan...
# 2                                     ALANA ABRAMSON
# 3  EMILY SHAPIRO Aaron Katersky Josh Margolin Mik...
# 4                                      Candace Smith
#
#                                                 text  \
# 0  With the Hillary Clinton-Donald Trump debates ...
# 1  As police today captured the man wanted for qu...
# 2  One day after explosive devices were discovere...
# 3  Ahmad Khan Rahami, earlier named a person of i...
# 4  Donald Trump's surrogates and leading supporte...
#
#                                                  url label  readability  \
# 0  http://abcnews.go.com/Politics/impact-debates-...  real        56.93
# 1  http://abcnews.go.com/US/source-suspect-wanted...  real        62.34
# 2  http://abcnews.go.com/Politics/donald-trump-re...  real        51.85
# 3  http://abcnews.go.com/US/bombing-incidences-ny...  real        69.79
# 4  http://abcnews.go.com/Politics/trump-surrogate...  real        46.44
#
#    read_grade  compound    neg           ...             compound_text  \
# 0         6.8    0.0000  0.000           ...                    0.9682
# 1         6.8   -0.6597  0.435           ...                   -0.9882
# 2         8.8    0.0000  0.000           ...                   -0.7769
# 3         6.0   -0.8271  0.554           ...                   -0.9912
# 4         8.8    0.0000  0.000           ...                   -0.7303
#
#    neg_text  neu_text  pos_text  punctuation_title  punctuation_text  \
# 0     0.061     0.851     0.089                  2               256
# 1     0.095     0.860     0.045                  0               110
# 2     0.086     0.887     0.028                  0                41
# 3     0.087     0.864     0.049                  1               200
# 4     0.074     0.859     0.067                  2               112
#
#    count_text  count_title  punctuation_ratio_text  punctuation_ratio_title
# 0        1152            6                0.222222                 0.333333
# 1         640            9                0.171875                 0.000000
# 2         213           11                0.192488                 0.000000
# 3        1158           10                0.172712                 0.100000
# 4         583            8                0.192110                 0.250000
#
# [5 rows x 24 columns]
# Index(['dataset', 'title', 'author', 'text', 'url', 'label', 'readability',
#        'read_grade', 'compound', 'neg', 'neu', 'pos', 'readability_text',
#        'read_grade_text', 'compound_text', 'neg_text', 'neu_text', 'pos_text',
#        'punctuation_title', 'punctuation_text', 'count_text', 'count_title',
#        'punctuation_ratio_text', 'punctuation_ratio_title'],
#       dtype='object')

# %% [markdown]
# #### Specific Keyword/Phrase Types of Linguistic Features
#
# First person.
# I, Me, My, Mine, we, us, our, ours
# We don't use he, they, because assumption is that many fake news try to do a us against them type of approach.
#
#
# Contrasting Conjuctures:
# But, However, Nonetheless, Yet, Even so, Nevertheless, Still,Notwithstanding, Although, Though, Even though, Much as, Notwithstanding, No matter, Despite, In spite of, For all, Regardless of, Notwithstanding

# %%
# %%time
# Tokenize the columns


text_columns = df[['title' ,'text']]
text_columns['title'] = text_columns['title'].str.lower()
text_columns['text'] = text_columns['text'].str.lower()
# Out:
# C:\Users\Alton\Miniconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# Wall time: 1.58 s
# C:\Users\Alton\Miniconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# %%time

with concurrent.futures.ProcessPoolExecutor(max_workers=4) as executor:
    titles_tokenize = text_columns['title'] 
    text_tokeinze = text_columns['text']
    titles_tokens = executor.map(nltk.word_tokenize, titles_tokenize, chunksize=100)
    text_tokens = executor.map(nltk.word_tokenize, text_tokeinze, chunksize=100)
# Out:
# Wall time: 16.4 s

# %%
# %%time
titles_tokens = pd.DataFrame({'titles_tokens':list(titles_tokens)})
text_tokens = pd.DataFrame({'text_tokens':list(text_tokens)})

text_columns = pd.concat([titles_tokens, text_tokens], axis=1)
# Out:
# Wall time: 11 ms

# %%
text_columns.head()
# Out:
#                                        titles_tokens  \
# 0   [the, impact, of, debates, ?, it, 's, debatable]
# 1  [details, emerge, about, nyc, bomb, suspect, a...
# 2  [donald, trump, repeats, calls, for, police, p...
# 3  [ny, ,, nj, bombings, suspect, charged, with, ...
# 4  [trump, surrogates, push, narrative, that, cli...
#
#                                          text_tokens
# 0  [with, the, hillary, clinton-donald, trump, de...
# 1  [as, police, today, captured, the, man, wanted...
# 2  [one, day, after, explosive, devices, were, di...
# 3  [ahmad, khan, rahami, ,, earlier, named, a, pe...
# 4  [donald, trump, 's, surrogates, and, leading, ...

# %%
# %%time

text_columns['title_counts'] = text_columns['titles_tokens'].apply(lambda x: Counter(x))
text_columns['text_counts'] = text_columns['text_tokens'].apply(lambda x: Counter(x))
# Out:
# Wall time: 2.33 s

# %%
string_list = (['but', 'however', 'nonetheless', 'yet', 
               'even', 'nevertheless', 'still',
               'notwithstanding', 'although', 'though', 
               'notwithstanding', 'despite', 'spite', 
               'regardless', 'notwithstanding'])

possessive_list = ['i', 'me', 'my', 'mine', 'we', 'us', 'our', 'ours']

# %%
# %%time
text_columns['text_totals'] = text_columns['text_counts'].apply(lambda x: sum(x.values()))
text_columns['text_exclusive_ratio'] = text_columns['text_counts'].apply(lambda x: (sum(x.get(w, 0) for w in string_list)))
text_columns['text_exclusive_ratio'] = text_columns['text_exclusive_ratio']/text_columns['text_totals']
# Out:
# Wall time: 308 ms

# %%
text_columns['possessive_ratio'] = text_columns['text_counts'].apply(lambda x: (sum(x.get(w, 0) for w in possessive_list)))
text_columns['possessive_ratio'] = text_columns['possessive_ratio']/text_columns['text_totals']

# %%
text_columns.head()
df.head()
# Out:
#                                        titles_tokens  \
# 0   [the, impact, of, debates, ?, it, 's, debatable]
# 1  [details, emerge, about, nyc, bomb, suspect, a...
# 2  [donald, trump, repeats, calls, for, police, p...
# 3  [ny, ,, nj, bombings, suspect, charged, with, ...
# 4  [trump, surrogates, push, narrative, that, cli...
#
#                                          text_tokens  \
# 0  [with, the, hillary, clinton-donald, trump, de...
# 1  [as, police, today, captured, the, man, wanted...
# 2  [one, day, after, explosive, devices, were, di...
# 3  [ahmad, khan, rahami, ,, earlier, named, a, pe...
# 4  [donald, trump, 's, surrogates, and, leading, ...
#
#                                         title_counts  \
# 0  {'the': 1, 'impact': 1, 'of': 1, 'debates': 1,...
# 1  {'details': 1, 'emerge': 1, 'about': 1, 'nyc':...
# 2  {'donald': 1, 'trump': 1, 'repeats': 1, 'calls...
# 3  {'ny': 1, ',': 1, 'nj': 1, 'bombings': 1, 'sus...
# 4  {'trump': 1, 'surrogates': 1, 'push': 1, 'narr...
#
#                                          text_counts  text_totals  \
# 0  {'with': 2, 'the': 66, 'hillary': 2, 'clinton-...         1355
# 1  {'as': 4, 'police': 5, 'today': 2, 'captured':...          717
# 2  {'one': 1, 'day': 1, 'after': 2, 'explosive': ...          252
# 3  {'ahmad': 1, 'khan': 1, 'rahami': 9, ',': 59, ...         1307
# 4  {'donald': 1, 'trump': 9, ''s': 8, 'surrogates...          691
#
#    text_exclusive_ratio  possessive_ratio
# 0              0.014022          0.002952
# 1              0.008368          0.001395
# 2              0.003968          0.019841
# 3              0.005356          0.010712
# 4              0.004342          0.014472
#     dataset                                              title  \
# 0  Buzzfeed              The Impact of Debates? It's Debatable
# 1  Buzzfeed  Details Emerge About NYC Bomb Suspect Ahmad Kh...
# 2  Buzzfeed  Donald Trump Repeats Calls for Police Profilin...
# 3  Buzzfeed  NY, NJ Bombings Suspect Charged With Attempted...
# 4  Buzzfeed  Trump Surrogates Push Narrative That Clinton S...
#
#                                               author  \
# 0                                        GARY LANGER
# 1  Brian Ross Rhonda Schwartz Mike Levine Stephan...
# 2                                     ALANA ABRAMSON
# 3  EMILY SHAPIRO Aaron Katersky Josh Margolin Mik...
# 4                                      Candace Smith
#
#                                                 text  \
# 0  With the Hillary Clinton-Donald Trump debates ...
# 1  As police today captured the man wanted for qu...
# 2  One day after explosive devices were discovere...
# 3  Ahmad Khan Rahami, earlier named a person of i...
# 4  Donald Trump's surrogates and leading supporte...
#
#                                                  url label  readability  \
# 0  http://abcnews.go.com/Politics/impact-debates-...  real        56.93
# 1  http://abcnews.go.com/US/source-suspect-wanted...  real        62.34
# 2  http://abcnews.go.com/Politics/donald-trump-re...  real        51.85
# 3  http://abcnews.go.com/US/bombing-incidences-ny...  real        69.79
# 4  http://abcnews.go.com/Politics/trump-surrogate...  real        46.44
#
#    read_grade  compound    neg           ...             compound_text  \
# 0         6.8    0.0000  0.000           ...                    0.9682
# 1         6.8   -0.6597  0.435           ...                   -0.9882
# 2         8.8    0.0000  0.000           ...                   -0.7769
# 3         6.0   -0.8271  0.554           ...                   -0.9912
# 4         8.8    0.0000  0.000           ...                   -0.7303
#
#    neg_text  neu_text  pos_text  punctuation_title  punctuation_text  \
# 0     0.061     0.851     0.089                  2               256
# 1     0.095     0.860     0.045                  0               110
# 2     0.086     0.887     0.028                  0                41
# 3     0.087     0.864     0.049                  1               200
# 4     0.074     0.859     0.067                  2               112
#
#    count_text  count_title  punctuation_ratio_text  punctuation_ratio_title
# 0        1152            6                0.222222                 0.333333
# 1         640            9                0.171875                 0.000000
# 2         213           11                0.192488                 0.000000
# 3        1158           10                0.172712                 0.100000
# 4         583            8                0.192110                 0.250000
#
# [5 rows x 24 columns]

# %%
df2 = pd.concat([df, text_columns['text_exclusive_ratio'], text_columns['possessive_ratio']], axis=1)

# %%
df2.tail()
# Out:
#                dataset                                     title  \
# 11437  Wang-PolitiFact  U.S. Representative, Florida District 23
# 11438  Wang-PolitiFact                                  Governor
# 11439  Wang-PolitiFact                              U.S. Senator
# 11440  Wang-PolitiFact             U.S. House of Representatives
# 11441  Wang-PolitiFact                              U.S. Senator
#
#                          author  \
# 11437  debbie-wasserman-schultz
# 11438                rick-scott
# 11439              jeff-merkley
# 11440               john-carter
# 11441                 tim-kaine
#
#                                                     text  \
# 11437  President Obama has the most border patrols an...
# 11438  Most of the newspapers that endorsed Alex Sink...
# 11439  60 percent of the jobs lost in the 2008 recess...
# 11440  About 40 percent of U.S. illegal immigrants ca...
# 11441  Gov. Pence said, inarguably, Vladimir Putin is...
#
#                                                     url label  readability  \
# 11437                             an interview on MSNBC  real        -1.29
# 11438                                          a debate  real       -47.99
# 11439  a talk to the Human Services Coalition of Oregon  real        35.61
# 11440                                    a news article  real        33.58
# 11441    the vice presidential debate in Farmville, Va.  real        35.61
#
#        read_grade  compound  neg        ...         neu_text  pos_text  \
# 11437        14.7       0.0  0.0        ...            0.876     0.124
# 11438        20.2       0.0  0.0        ...            0.714     0.286
# 11439         8.8       0.0  0.0        ...            0.812     0.000
# 11440         9.6       0.0  0.0        ...            0.819     0.053
# 11441         8.8       0.0  0.0        ...            0.791     0.209
#
#        punctuation_title  punctuation_text  count_text  count_title  \
# 11437                  3                 1          18            5
# 11438                  0                 1          12            1
# 11439                  2                 5          24            2
# 11440                  2                 5          26            4
# 11441                  2                 4          13            2
#
#        punctuation_ratio_text  punctuation_ratio_title  text_exclusive_ratio  \
# 11437                0.055556                      0.6                   0.0
# 11438                0.083333                      0.0                   0.0
# 11439                0.208333                      1.0                   0.0
# 11440                0.192308                      0.5                   0.0
# 11441                0.307692                      1.0                   0.0
#
#        possessive_ratio
# 11437               0.0
# 11438               0.0
# 11439               0.0
# 11440               0.0
# 11441               0.0
#
# [5 rows x 26 columns]

# %%
# df2.to_csv('data_Wang_expandedfeatures.csv', index=False) # this has the new ratios for possessive and exclusive words

# %%
# df = pd.read_csv('data12-05-2018.csv')

# %%
wang = pd.read_csv('data_Wang_expandedfeatures.csv')
no_wang = pd.read_csv('data_expandedfeatures.csv')

# %%
wang[1000:3000]
# Out:
#               dataset                                              title  \
# 1000         Buzzfeed          How to fix our disaster recovery strategy
# 1001         Buzzfeed  Schumer transfers millions to Dems in bid for ...
# 1002         Buzzfeed  If you can't remember all your lies, you're te...
# 1003         Buzzfeed  Government funding battle could SLIP to next w...
# 1004         Buzzfeed  George Soros to give $500 million to migrant, ...
# 1005         Buzzfeed                            Worst. President. Ever.
# 1006         Buzzfeed  New York New Siena poll finds Clinton, Schumer...
# 1007         Buzzfeed  Trump hits Clinton on Islamic State: ‘It is ti...
# 1008         Buzzfeed  Bono: ‘Trump is potentially the worst idea tha...
# 1009         Buzzfeed      Jack Welch outlines why he's supporting Trump
# 1010         Buzzfeed  Florida ‘Trump did not get a pass,’ defiant Bo...
# 1011         Buzzfeed         Ivanka Trump heads to Capitol Hill Tuesday
# 1012         Buzzfeed    Trump campaign reporters no longer in motorcade
# 1013         Buzzfeed  Clinton: I'm 'appalled' Trump hasn't apologize...
# 1014         Buzzfeed          Obama warns against strongman governments
# 1015         Buzzfeed                Boehner joining Squire Patton Boggs
# 1016         Buzzfeed           Reid accuses Trump of overstating wealth
# 1017         Buzzfeed  Trump needles Clinton: ‘Sleep well Hillary — s...
# 1018         Buzzfeed  Clinton: ‘The next 50 days will determine the ...
# 1019         Buzzfeed        President of the Philippines to EU: F–k you
# 1020         Buzzfeed  New Jersey Christie among the most unpopular g...
# 1021         Buzzfeed  NRA warns voters that Clinton will leave them ...
# 1022         Buzzfeed  Clinton: Tulsa shooting by police should be 'i...
# 1023         Buzzfeed  Warren tells Wells Fargo's CEO to resign, call...
# 1024         Buzzfeed          Clinton camp pushes 'Mormons for Hillary'
# 1025         Buzzfeed  Florida Fla. poll: Clinton leads Trump, who's ...
# 2971                0.132812                 0.000000              0.009901
# 2972                0.132988                 0.181818              0.007582
# 2973                0.192063                 0.300000              0.005115
# 2974                0.150276                 0.090909              0.006554
# 2975                0.224490                 0.000000              0.006279
# 2976                0.178248                 0.250000              0.005168
# 2977                0.280347                 0.125000              0.004706
# 2978                0.090278                 0.100000              0.004107
# 2979                0.106164                 0.100000              0.008798
# 2980                0.143275                 0.000000              0.010017
# 2981                0.130350                 0.000000              0.004651
# 2982                0.236726                 0.055556              0.006981
# 2983                0.220779                 0.100000              0.000000
# 2984                0.165381                 0.333333              0.004950
# 2985                0.200000                 0.250000              0.000000
# 2986                0.141786                 0.000000              0.005467
# 2987                0.260870                 0.166667              0.000000
# 2988                0.155000                 0.444444              0.001248
# 2989                0.153543                 0.250000              0.009046
# 2990                0.105464                 0.181818              0.005447
# 2991                0.104677                 0.625000              0.005848
# 2992                0.161547                 0.090909              0.007663
# 2993                0.112683                 0.100000              0.009346
# 2994                0.130832                 0.052632              0.009167
# 2995                0.152027                 0.333333              0.018568
# 2996                0.154062                 0.000000              0.007177
# 2997                0.142289                 0.166667              0.005394
# 2998                0.234097                 0.272727              0.007148
# 2999                0.163451                 0.000000              0.004850
#
#       possessive_ratio
# 1000          0.009964
# 1001          0.007965
# 1002          0.013624
# 1003          0.007130
# 1004          0.017897
# 1005          0.008372
# 1006          0.000000
# 1007          0.013937
# 1008          0.024631
# 1009          0.017456
# 1010          0.011329
# 1011          0.000000
# 1012          0.004274
# 1013          0.041872
# 1014          0.013975
# 1015          0.012579
# 1016          0.013921
# 1017          0.023810
# 1018          0.034765
# 1019          0.004557
# 1020          0.000000
# 1021          0.000000
# 1022          0.047794
# 1023          0.009174
# 1024          0.004566
# 1025          0.001664
# 1026          0.020958
# 1027          0.022792
# 1028          0.018433
# 1029          0.000000
# ...                ...
# 2970          0.006494
# 2971          0.003300
# 2972          0.015921
# 2973          0.010230
# 2974          0.008427
# 2975          0.001570
# 2976          0.002584
# 2977          0.000000
# 2978          0.028747
# 2979          0.002933
# 2980          0.024207
# 2981          0.018605
# 2982          0.006981
# 2983          0.010417
# 2984          0.012023
# 2985          0.000000
# 2986          0.004283
# 2987          0.000000
# 2988          0.012484
# 2989          0.006579
# 2990          0.011983
# 2991          0.007797
# 2992          0.005747
# 2993          0.046284
# 2994          0.012500
# 2995          0.074271
# 2996          0.004785
# 2997          0.019555
# 2998          0.001430
# 2999          0.009699
#
# [2000 rows x 26 columns]

# %%
no_wang = wang[:-2500]

# %%
no_wang.to_csv('data_expandedfeatures.csv', index=False)

# %%
no_wang['dataset'].value_counts()
wang['dataset'].value_counts()
# Out:
# Risdal-McIntire    6335
# Buzzfeed           1627
# Rosas-Celebrity     500
# Rosas-News          480
# Name: dataset, dtype: int64
# Risdal-McIntire    6335
# Wang-PolitiFact    2500
# Buzzfeed           1627
# Rosas-Celebrity     500
# Rosas-News          480
# Name: dataset, dtype: int64

# %%
wang.columns == no_wang.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
df.head()
df2.head()
# Out:
#     dataset                                              title  \
# 0  Buzzfeed              The Impact of Debates? It's Debatable
# 1  Buzzfeed  Details Emerge About NYC Bomb Suspect Ahmad Kh...
# 2  Buzzfeed  Donald Trump Repeats Calls for Police Profilin...
# 3  Buzzfeed  NY, NJ Bombings Suspect Charged With Attempted...
# 4  Buzzfeed  Trump Surrogates Push Narrative That Clinton S...
#
#                                               author  \
# 0                                        GARY LANGER
# 1  Brian Ross Rhonda Schwartz Mike Levine Stephan...
# 2                                     ALANA ABRAMSON
# 3  EMILY SHAPIRO Aaron Katersky Josh Margolin Mik...
# 4                                      Candace Smith
#
#                                                 text  \
# 0  With the Hillary Clinton-Donald Trump debates ...
# 1  As police today captured the man wanted for qu...
# 2  One day after explosive devices were discovere...
# 3  Ahmad Khan Rahami, earlier named a person of i...
# 4  Donald Trump's surrogates and leading supporte...
#
#                                                  url label  readability  \
# 0  http://abcnews.go.com/Politics/impact-debates-...  real        56.93
# 1  http://abcnews.go.com/US/source-suspect-wanted...  real        62.34
# 2  http://abcnews.go.com/Politics/donald-trump-re...  real        51.85
# 3  http://abcnews.go.com/US/bombing-incidences-ny...  real        69.79
# 4  http://abcnews.go.com/Politics/trump-surrogate...  real        46.44
#
#    read_grade  compound    neg        ...         neu_text  pos_text  \
# 0         6.8    0.0000  0.000        ...            0.851     0.089
# 1         6.8   -0.6597  0.435        ...            0.860     0.045
# 2         8.8    0.0000  0.000        ...            0.887     0.028
# 3         6.0   -0.8271  0.554        ...            0.864     0.049
# 4         8.8    0.0000  0.000        ...            0.859     0.067
#
#    punctuation_title  punctuation_text  count_text  count_title  \
# 0                  2               256        1152            6
# 1                  0               110         640            9
# 2                  0                41         213           11
# 3                  1               200        1158           10
# 4                  2               112         583            8
#
#    punctuation_ratio_text  punctuation_ratio_title  text_exclusive_ratio  \
# 0                0.222222                 0.333333              0.014022
# 1                0.171875                 0.000000              0.008368
# 2                0.192488                 0.000000              0.003968
# 3                0.172712                 0.100000              0.005356
# 4                0.192110                 0.250000              0.004342
#
#    possessive_ratio
# 0          0.002952
# 1          0.001395
# 2          0.019841
# 3          0.010712
# 4          0.014472
#
# [5 rows x 26 columns]
#     dataset                                              title  \
# 0  Buzzfeed              The Impact of Debates? It's Debatable
# 1  Buzzfeed  Details Emerge About NYC Bomb Suspect Ahmad Kh...
# 2  Buzzfeed  Donald Trump Repeats Calls for Police Profilin...
# 3  Buzzfeed  NY, NJ Bombings Suspect Charged With Attempted...
# 4  Buzzfeed  Trump Surrogates Push Narrative That Clinton S...
#
#                                                 text  \
# 0  With the Hillary Clinton-Donald Trump debates ...
# 1  As police today captured the man wanted for qu...
# 2  One day after explosive devices were discovere...
# 3  Ahmad Khan Rahami, earlier named a person of i...
# 4  Donald Trump's surrogates and leading supporte...
#
#                                                  url label  readability  \
# 0  http://abcnews.go.com/Politics/impact-debates-...  real        56.93
# 1  http://abcnews.go.com/US/source-suspect-wanted...  real        62.34
# 2  http://abcnews.go.com/Politics/donald-trump-re...  real        51.85
# 3  http://abcnews.go.com/US/bombing-incidences-ny...  real        69.79
# 4  http://abcnews.go.com/Politics/trump-surrogate...  real        46.44
#
#    read_grade  compound    neg    neu        ...         neu_text  pos_text  \
# 0         6.8    0.0000  0.000  1.000        ...            0.851     0.089
# 1         6.8   -0.6597  0.435  0.565        ...            0.860     0.045
# 2         8.8    0.0000  0.000  1.000        ...            0.887     0.028
# 3         6.0   -0.8271  0.554  0.446        ...            0.864     0.049
# 4         8.8    0.0000  0.000  1.000        ...            0.859     0.067
#
#    punctuation_title  punctuation_text  count_text  count_title  \
# 0                  2               256        1152            6
# 1                  0               110         640            9
# 2                  0                41         213           11
# 3                  1               200        1158           10
# 4                  2               112         583            8
#
#    punctuation_ratio_text  punctuation_ratio_title  text_exclusive_ratio  \
# 0                0.222222                 0.333333              0.014022
# 1                0.171875                 0.000000              0.008368
# 2                0.192488                 0.000000              0.003968
# 3                0.172712                 0.100000              0.005356
# 4                0.192110                 0.250000              0.004342
#
#    possessive_ratio
# 0          0.002952
# 1          0.001395
# 2          0.019841
# 3          0.010712
# 4          0.014472
#
# [5 rows x 25 columns]
